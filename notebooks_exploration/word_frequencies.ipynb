# %%
import sys
sys.path.insert(0, '..')

import pandas as pd
from helpers import *
from libraries.charts import *

# %%
df = pd.read_excel(path_data + "IOW - 3 - Cleaned Text.xlsx")

# %%
df.head()
# Out:
#                             WORD_association            WORD_person  \
# 0  confidence,believable,reliable,conviction  No one in particular.
# 1                                       fund  No one in particular.
# 2                                      loyal                 Family
# 3                          good,faith,honest                 Family
# 4                   faith,believe,confidence  No one in particular.
#
#                 BRAND_association     BRAND_name  \
# 0      make,label,trade-name,logo          Dyson
# 1                             NaN            NaN
# 2  natural,original,genuine,clean     Yo-yo bear
# 3    clothe,holiday,fashion,value      BonMarche
# 4    reliable,efficient,well-made  Mercedes BENZ
#
#                                   PERSON_association   PERSON_relationship  \
# 0                                  love,friend,loyal  Husband or boyfriend
# 1                       obese,kind,loving,old,caring   Other family member
# 2             love,loyal,fun,happy,contentment,peace  Husband or boyfriend
# 3  good,faithful,honest,steadfast,generou,friendl...  Husband or boyfriend
# 4                        helpful,generou,hardworking                Sister
#
#   PERSON_gender PERSON_gender_other                          SELF_association  \
# 0           NaN                 NaN        loyal,listener,carer,solver,helper
# 1        Female                 NaN                         honest,moral,good
# 2           NaN                 NaN                       honest,selfles,kind
# 3           NaN                 NaN  truthful,faithful,capable,honest,genuine
# 4           NaN                 NaN          reliable,helpful,tenaciou,honest
#
#                    QUESTION_trust languages  age     sex ethnicity  \
# 0                               3   English   60  Female     White
# 1                               5   English   45  Female     White
# 2                               4   English   37  Female     Mixed
# 3  1 - Most people can be trusted   English   67  Female     White
# 4                               2   English   58    Male     Black
#
#   country_of_birth country_of_residence     nationality first_language  \
# 0   United Kingdom       United Kingdom  United Kingdom        English
# 1   United Kingdom       United Kingdom  United Kingdom        English
# 2   United Kingdom       United Kingdom  United Kingdom        English
# 3   United Kingdom       United Kingdom  United Kingdom        English
# 4            Ghana       United Kingdom  United Kingdom        English
#
#      is_student                                         employment
# 0            No  Not in paid work (e.g. homemaker', 'retired or...
# 1            No                                       DATA_EXPIRED
# 2  DATA_EXPIRED                                       DATA_EXPIRED
# 3            No  Not in paid work (e.g. homemaker', 'retired or...
# 4            No                                          Full-Time

# %%
from libraries.charts import *

word_count(
    pd.concat([
        df.WORD_association.str.split(",").explode().value_counts().head(20).sort_values(),
        df.PERSON_association.str.split(",").explode().value_counts().head(20).sort_values(),
        df.BRAND_association.str.split(",").explode().value_counts().head(20).sort_values(),
        df.SELF_association.str.split(",").explode().value_counts().head(20).sort_values()
        ])
    
, ["WORD", "PERSON", "BRAND","SELF", "Associations by Question Type"], [BLUE, TURK, ORANGE, GREEN], "../plots/"+"associations_by_question.png", False)

# %%
import pandas as pd
import nltk
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()

stemmer.stem("honest")
# Out:
# 'honest'

# %%
BLUE = cmap[5]
TURK = cmap[3]
ORANGE = cmap[1]
GREEN = cmap[2]
